# %% [markdown]
# import important library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/Student_Attendance.csv')

# %% [markdown]
# Calculate Attendance %

# %%
df['AttendancePercent'] = round((df['ClassesAttended'] / df['TotalClasses']) * 100, 2)

# %% [markdown]
# Flag Attendance Category

# %%
def categorize(p):
    if p >= 75:
        return 'High (>=75%)'
    elif p >= 50:
        return 'Medium (50-74%)'
    else:
        return 'Low (<50%)'

df['Category'] = df['AttendancePercent'].apply(categorize)

df['Flag'] = df['AttendancePercent']

# %% [markdown]
# Display Final Table

# %%
print("\n📋 Final Attendance Table:\n")
print(df[['StudentID', 'Name', 'TotalClasses', 'ClassesAttended', 'AttendancePercent', 'Category', 'Flag']])
# Out:
# 📋 Final Attendance Table:
#
#    StudentID           Name  TotalClasses  ClassesAttended  AttendancePercent  \
# 0       S001    Amit Sharma            50               45               90.0
# 1       S002     Neha Singh            50               35               70.0
# 2       S003      Raj Patel            50               20               40.0
# 3       S004    Sneha Verma            50               18               36.0
# 4       S005   Aditya Mehra            50               27               54.0
# 5       S006     Diya Gupta            50               50              100.0
# 6       S007     Vikram Rao            50               15               30.0
# 7       S008      Isha Jain            50               30               60.0
# 8       S009   Karan Thakur            50               22               44.0
# 9       S010      Meena Das            50               40               80.0
# 10      S011  Harshit Yadav            50               43               86.0
# ...

# %% [markdown]
#  Bar Chart: Attendance % per student

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Name', y='AttendancePercent', data=df, palette='coolwarm')
plt.title('Attendance Percentage per Student')
plt.xticks(rotation=45)
plt.ylabel('Attendance %')
plt.xlabel('Student')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3776684126.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Name', y='AttendancePercent', data=df, palette='coolwarm')

# %% [markdown]
#  Pie Chart: Attendance Category Split

# %%
plt.figure(figsize=(6, 6))
df['Category'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, colors=['#4CAF50', '#FFC107', '#F44336'])
plt.title('Attendance Category Distribution')
plt.ylabel('')
plt.tight_layout()
plt.show()
